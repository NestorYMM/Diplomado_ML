# %% [markdown]
# # Obtención de datos

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from sklearn.datasets import load_breast_cancer
cancer_dataset = load_breast_cancer()
df = pd.DataFrame(cancer_dataset.data, columns = cancer_dataset.feature_names)
df['Target'] = cancer_dataset.target[df.index]
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  Target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
# 3          0.6638                  0.17300       0
# 4          0.2364                  0.07678       0
#
# [5 rows x 31 columns]

# %%
x = df.drop("Target", axis = 1)
y = df.Target

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.30, random_state=100)

# %% [markdown]
# # Creando nuestro primer bosque aleatorio

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100, random_state=100);

# %%
clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=100)

# %%
y_train_predict = clf.predict(x_train)
y_test_predict = clf.predict(x_test)

# %%
clf.estimators_
# Out:
# [DecisionTreeClassifier(max_features='sqrt', random_state=186422792),
#  DecisionTreeClassifier(max_features='sqrt', random_state=735107864),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1195587395),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1769725799),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1823289175),
#  DecisionTreeClassifier(max_features='sqrt', random_state=113311823),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1480802224),
#  DecisionTreeClassifier(max_features='sqrt', random_state=638252938),
#  DecisionTreeClassifier(max_features='sqrt', random_state=20267358),
#  DecisionTreeClassifier(max_features='sqrt', random_state=673068980),
#  DecisionTreeClassifier(max_features='sqrt', random_state=522135394),
#  DecisionTreeClassifier(max_features='sqrt', random_state=800870453),
#  DecisionTreeClassifier(max_features='sqrt', random_state=733361730),
#  DecisionTreeClassifier(max_features='sqrt', random_state=902405858),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1399526926),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1944503074),
#  DecisionTreeClassifier(max_features='sqrt', random_state=587150321),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1589750512),
#  DecisionTreeClassifier(max_features='sqrt', random_state=322523416),
#  DecisionTreeClassifier(max_features='sqrt', random_state=273507983),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1680714980),
#  DecisionTreeClassifier(max_features='sqrt', random_state=533915499),
#  DecisionTreeClassifier(max_features='sqrt', random_state=898516284),
#  DecisionTreeClassifier(max_features='sqrt', random_state=100277818),
#  DecisionTreeClassifier(max_features='sqrt', random_state=795978640),
#  DecisionTreeClassifier(max_features='sqrt', random_state=267560443),
#  DecisionTreeClassifier(max_features='sqrt', random_state=465475209),
#  DecisionTreeClassifier(max_features='sqrt', random_state=24984669),
#  DecisionTreeClassifier(max_features='sqrt', random_state=943593558),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1320372610),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2055673499),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1933526892),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1338668932),
#  DecisionTreeClassifier(max_features='sqrt', random_state=543975839),
#  DecisionTreeClassifier(max_features='sqrt', random_state=738481025),
#  DecisionTreeClassifier(max_features='sqrt', random_state=339250317),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1358174965),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1337251539),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1177137764),
#  DecisionTreeClassifier(max_features='sqrt', random_state=568583172),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1854155355),
#  DecisionTreeClassifier(max_features='sqrt', random_state=856240059),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1889913667),
#  DecisionTreeClassifier(max_features='sqrt', random_state=609734791),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1364293681),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1803988399),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1443589825),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1283664189),
#  DecisionTreeClassifier(max_features='sqrt', random_state=753382158),
#  DecisionTreeClassifier(max_features='sqrt', random_state=295259831),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1601301447),
#  DecisionTreeClassifier(max_features='sqrt', random_state=767185659),
#  DecisionTreeClassifier(max_features='sqrt', random_state=24431952),
#  DecisionTreeClassifier(max_features='sqrt', random_state=139902978),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1084162937),
#  DecisionTreeClassifier(max_features='sqrt', random_state=630035049),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1269860830),
#  DecisionTreeClassifier(max_features='sqrt', random_state=610166163),
#  DecisionTreeClassifier(max_features='sqrt', random_state=65519586),
#  DecisionTreeClassifier(max_features='sqrt', random_state=349562943),
#  DecisionTreeClassifier(max_features='sqrt', random_state=424529077),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2058105115),
#  DecisionTreeClassifier(max_features='sqrt', random_state=445837112),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1659657454),
#  DecisionTreeClassifier(max_features='sqrt', random_state=451605873),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1891782558),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1640434608),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1738419503),
#  DecisionTreeClassifier(max_features='sqrt', random_state=156663463),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1899466605),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1676804902),
#  DecisionTreeClassifier(max_features='sqrt', random_state=129378476),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2065539346),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1185433792),
#  DecisionTreeClassifier(max_features='sqrt', random_state=257448888),
#  DecisionTreeClassifier(max_features='sqrt', random_state=218864546),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1677382069),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1636697802),
#  DecisionTreeClassifier(max_features='sqrt', random_state=330289425),
#  DecisionTreeClassifier(max_features='sqrt', random_state=125695560),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1041442317),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1962271338),
#  DecisionTreeClassifier(max_features='sqrt', random_state=559135774),
#  DecisionTreeClassifier(max_features='sqrt', random_state=755146769),
#  DecisionTreeClassifier(max_features='sqrt', random_state=351509557),
#  DecisionTreeClassifier(max_features='sqrt', random_state=508106820),
#  DecisionTreeClassifier(max_features='sqrt', random_state=87785394),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1558839784),
#  DecisionTreeClassifier(max_features='sqrt', random_state=902057307),
#  DecisionTreeClassifier(max_features='sqrt', random_state=321550811),
#  DecisionTreeClassifier(max_features='sqrt', random_state=191920083),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1396271797),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1155840846),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1443675136),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1076727821),
#  DecisionTreeClassifier(max_features='sqrt', random_state=323818681),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1227912652),
#  DecisionTreeClassifier(max_features='sqrt', random_state=48965994),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1513525379),
#  DecisionTreeClassifier(max_features='sqrt', random_state=207964742)]

# %% [markdown]
# ### Importando un modelo obtenido por el bosque aleatorio.

# %%
arbol = clf.estimators_[0]

# %%
feature_labels = []
for col in x.columns:
    feature_labels.append(col)

print(feature_labels)
# Out:
# ['mean radius', 'mean texture', 'mean perimeter', 'mean area', 'mean smoothness', 'mean compactness', 'mean concavity', 'mean concave points', 'mean symmetry', 'mean fractal dimension', 'radius error', 'texture error', 'perimeter error', 'area error', 'smoothness error', 'compactness error', 'concavity error', 'concave points error', 'symmetry error', 'fractal dimension error', 'worst radius', 'worst texture', 'worst perimeter', 'worst area', 'worst smoothness', 'worst compactness', 'worst concavity', 'worst concave points', 'worst symmetry', 'worst fractal dimension']

# %%
class_labels = ['malignant', 'benign']

# %%
from sklearn.tree import export_graphviz

export_graphviz(arbol, out_file = "RandomForest0.ps", 
                feature_names = feature_labels, 
                class_names = class_labels,
                filled = True,
                rounded = True
               )

# %% [markdown]
# ### Tu árbol debe ser muy parecido al que tienes aquí en la libreta.

# %% [markdown]
# <center><img src="img/RandomForest1.png" width = "100%"></center>

# %% [markdown]
# ### Usando el ciclo "for" podemos grabar todos los diferentes árboles que produce el bosque.

# %%
feature_labels = []
for col in x.columns:
    feature_labels.append(col)

class_labels = ['malignant', 'benign']

n = clf.n_estimators

for i in range(n):
    arbol = clf.estimators_[i]
    file_name = str(i) + ".ps"
    export_graphviz(arbol, out_file = file_name, 
                feature_names = feature_labels, 
                class_names = class_labels,
                filled = True,
                rounded = True
               )

# %%
from sklearn.metrics import classification_report
print(classification_report(y_train, y_train_predict))
print(classification_report(y_test, y_test_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       143
#            1       1.00      1.00      1.00       255
#
#     accuracy                           1.00       398
#    macro avg       1.00      1.00      1.00       398
# weighted avg       1.00      1.00      1.00       398
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.90      0.93        69
#            1       0.93      0.98      0.96       102
#
#     accuracy                           0.95       171
#    macro avg       0.95      0.94      0.94       171
# weighted avg       0.95      0.95      0.95       171

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_train, y_train_predict)
sns.heatmap(cm, linewidth = 0.5, annot = True, cmap = 'Reds', fmt = 'g')
plt.ylabel('Valores predecidos')
plt.xlabel('Valores reales')
plt.title('Comparación con valores de entrenamiento')
plt.show()

# %%
cm = confusion_matrix(y_test, y_test_predict)
sns.heatmap(cm, linewidth = 0.5, annot = True, cmap = 'Reds', fmt = 'g')
plt.ylabel('Valores predecidos')
plt.xlabel('Valores reales')
plt.title('Comparación con valores de prueba')
plt.show()

# %% [markdown]
# # Visualizando la importancia de las características al modelo

# %%
clf.feature_importances_
# Out:
# array([0.06082575, 0.01203414, 0.06658116, 0.04061686, 0.00593186,
#        0.00666543, 0.0483094 , 0.1377072 , 0.00651761, 0.0033341 ,
#        0.01013671, 0.00402787, 0.01082128, 0.02542445, 0.00367185,
#        0.00539079, 0.00956575, 0.0063813 , 0.00521718, 0.0043603 ,
#        0.08902617, 0.0156199 , 0.12319549, 0.10808756, 0.01586751,
#        0.0171118 , 0.03159618, 0.11476145, 0.0067313 , 0.00448165])

# %%
feature_imp = pd.Series(clf.feature_importances_, index=x.columns)
feature_imp
# Out:
# mean radius                0.060826
# mean texture               0.012034
# mean perimeter             0.066581
# mean area                  0.040617
# mean smoothness            0.005932
# mean compactness           0.006665
# mean concavity             0.048309
# mean concave points        0.137707
# mean symmetry              0.006518
# mean fractal dimension     0.003334
# radius error               0.010137
# texture error              0.004028
# perimeter error            0.010821
# area error                 0.025424
# smoothness error           0.003672
# compactness error          0.005391
# concavity error            0.009566
# concave points error       0.006381
# symmetry error             0.005217
# fractal dimension error    0.004360
# worst radius               0.089026
# worst texture              0.015620
# worst perimeter            0.123195
# worst area                 0.108088
# worst smoothness           0.015868
# worst compactness          0.017112
# worst concavity            0.031596
# worst concave points       0.114761
# worst symmetry             0.006731
# worst fractal dimension    0.004482
# dtype: float64

# %%
feature_imp = feature_imp.sort_values(ascending = False)
feature_imp
# Out:
# mean concave points        0.137707
# worst perimeter            0.123195
# worst concave points       0.114761
# worst area                 0.108088
# worst radius               0.089026
# mean perimeter             0.066581
# mean radius                0.060826
# mean concavity             0.048309
# mean area                  0.040617
# worst concavity            0.031596
# area error                 0.025424
# worst compactness          0.017112
# worst smoothness           0.015868
# worst texture              0.015620
# mean texture               0.012034
# perimeter error            0.010821
# radius error               0.010137
# concavity error            0.009566
# worst symmetry             0.006731
# mean compactness           0.006665
# mean symmetry              0.006518
# concave points error       0.006381
# mean smoothness            0.005932
# compactness error          0.005391
# symmetry error             0.005217
# worst fractal dimension    0.004482
# fractal dimension error    0.004360
# texture error              0.004028
# smoothness error           0.003672
# mean fractal dimension     0.003334
# dtype: float64

# %%
plt.figure(figsize=(6,15))
sns.barplot(x = feature_imp, y = feature_imp.index)
plt.xlabel('Importancia')
plt.ylabel('Característica')
plt.title("Visualizando la importancia de cada Característica")
plt.show()

# %% [markdown]
# # Hagamos una base de datos resumida tomando en cuenta los cinco datos más representativos

# %%
feature_imp.head()
# Out:
# mean concave points     0.137707
# worst perimeter         0.123195
# worst concave points    0.114761
# worst area              0.108088
# worst radius            0.089026
# dtype: float64

# %%
feature_imp.index[0]
# Out:
# 'mean concave points'

# %%
columns = []
for i in range(5):
    columns.append(feature_imp.index[i])

columns
# Out:
# ['mean concave points',
#  'worst perimeter',
#  'worst concave points',
#  'worst area',
#  'worst radius']

# %%
df_reduced = pd.DataFrame(columns = columns)
df_reduced.head()
# Out:
# Empty DataFrame
# Columns: [mean concave points, worst perimeter, worst concave points, worst area, worst radius]
# Index: []

# %%
for i in range(5):
    df_reduced[feature_imp.index[i]] = df[feature_imp.index[i]]
    
df_reduced.head()
# Out:
#    mean concave points  worst perimeter  worst concave points  worst area  \
# 0              0.14710           184.60                0.2654      2019.0
# 1              0.07017           158.80                0.1860      1956.0
# 2              0.12790           152.50                0.2430      1709.0
# 3              0.10520            98.87                0.2575       567.7
# 4              0.10430           152.20                0.1625      1575.0
#
#    worst radius
# 0         25.38
# 1         24.99
# 2         23.57
# 3         14.91
# 4         22.54

# %%
x = df_reduced
y = df.Target

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.30, random_state=100)

clf = RandomForestClassifier(n_estimators=100, random_state=100)

clf.fit(x_train, y_train)

y_train_predict = clf.predict(x_train)
y_test_predict = clf.predict(x_test)

print(classification_report(y_train, y_train_predict))
print(classification_report(y_test, y_test_predict))

cm = confusion_matrix(y_train, y_train_predict)
sns.heatmap(cm, linewidth = 0.5, annot = True, cmap = 'Reds', fmt = 'g')
plt.ylabel('Valores predecidos')
plt.xlabel('Valores reales')
plt.title('Comparación con valores de entrenamiento')
plt.show()

cm = confusion_matrix(y_test, y_test_predict)
sns.heatmap(cm, linewidth = 0.5, annot = True, cmap = 'Reds', fmt = 'g')
plt.ylabel('Valores predecidos')
plt.xlabel('Valores reales')
plt.title('Comparación con valores de prueba')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       143
#            1       1.00      1.00      1.00       255
#
#     accuracy                           1.00       398
#    macro avg       1.00      1.00      1.00       398
# weighted avg       1.00      1.00      1.00       398
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.87      0.92        69
#            1       0.92      0.98      0.95       102
#
#     accuracy                           0.94       171
#    macro avg       0.94      0.92      0.93       171
# weighted avg       0.94      0.94      0.94       171

# %%
feature_imp = pd.Series(clf.feature_importances_, index = x.columns)
feature_imp = feature_imp.sort_values(ascending = False)

plt.figure(figsize=(6,4))
sns.barplot(x = feature_imp, y = feature_imp.index)
plt.xlabel('Importancia')
plt.ylabel('Característica')
plt.title("Visualizando la importancia de cada Característica")
plt.show()
