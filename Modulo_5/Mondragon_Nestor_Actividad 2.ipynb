# %% [markdown]
# ## Sección donde incluimos la mayoría de las librerias que utilizaremos en la actividad.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("whitegrid")
import numpy as np
import pandas as pd

# %% [markdown]
# ## Obtención del conjunto de los datos.

# %% [markdown]
# #### Instrucción 1:
# <p style='text-align: justify;'>Reproduce las siguiente celdas de código para importar la base de datos y obtener un poco de información descriptiva del dataframe con el que trabajaremos. Posterior a reproducir las cinco celdas, agrega una celda de tipo <b>markdown</b> en donde escribas de que trata la base de datos, incluyendo cuantos renglones y columnas tiene la base de datos.</p>

# %%
from sklearn.datasets import load_diabetes
diabetes = load_diabetes()

# %%
print(diabetes.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
df = pd.DataFrame(diabetes.data, columns = diabetes.feature_names)

# %%
df.head(10)
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5 -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# 6 -0.045472  0.050680 -0.047163 -0.015999 -0.040096 -0.024800  0.000779
# 7  0.063504  0.050680 -0.001895  0.066629  0.090620  0.108914  0.022869
# 8  0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# 9 -0.070900 -0.044642  0.039062 -0.033213 -0.012577 -0.034508 -0.024993
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# ...

# %%
df.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.293722e-17  1.130318e-17
# ...

# %% [markdown]
# ##### Respuesta
# <h1>Descripicón de base de datos</h1>
#
# <p>Esta base de datos contiene información de pacientes con diabetes (Tiene 10 columnas con distintos atributos de cada uno, como la edad, su genero, indice de masa corporal, entre otros) y una variable respuesta (O de interés), que es una medida cuantitativa que representa la progreción de la enfermedad en un año</p>
#
# <p>Contamos con una tabla que tiene 10 columnas (Cada una una variable), y 442 filas (Cada unaa instancia), cuyos datos se encuentran aparentemente normalizados.</p>
#
# <p>Especificamente se cuenta con las siguientes variables:</p>
#
# <ol>
#     <li>Age:</li>
#     Esta variable (La cual es cuantitativa, aunque devería ser discreta, se encuentra estandarizada, por lo que parenta ser contínua) esta normalizada pues cuenta con valores entre el -0.107 al 0.11, aunque en realidad hay solo 58 distintos valores que esta variable toma.
#     <li>Sex:</li>
#     Esta variable es cualitativa nominal binaria, pues se refiere al sexo del paciente, pero para poder tabularla, suele convertirse a una variable dummy (0 o 1), y posteriormente se normalizó, pues esta toma solo dos valores, los cuales son $0.05068012$ y  $-0.04464164$.
#     <br> Se tienen 207 registros con la variable $sex = 0.05068012$ y 235 con $sex=-0.044642$.
#     <li>bmi:</li>
#     Esta variable es cuantitativa contínua, pues es el indice de masa corporal del paciente, aunque al igual que las demás variables se encuentra estandarizada, por lo que toma valores desde $-0.09027529589850945$ al $0.17055522598064407$.
#     <li>Bp:</li>
#     Esta variable es cuantitativa contínua, pues es la preción sanguínea promedio del paciente, toma valores desde el $-0.11239880254408448$ hasta el $0.13204361674121307$.
#     <li>S1:</li>
#     Esta variable es cuantitativa contínua, pues es la cantidad de suero colestérico del paciente, y toma valores desde el $-0.12678066991651324$ hasta el $0.15391371315651542$.
#     <li>S2:</li>
#     Esta variable es cuantitativa contínua, pues es la cantidad de lipoproteinas de baja densidad presentes en la sangre del paciente, y toma valores desde el $-0.11561306597939897$ hasta el $0.19878798965729408$.
#     <li>S3:</li>
#     Esta variable es cuantitativa contínua, pues es la cantidad de lipoproteinas de alta densidad presentes en la sangre del paciente, y toma valores desde el $-0.10230705051741597$ hasta el $0.18117906039727852$".
#     <li>S4:</li>
#     Esta variable es cuantitativa contínua, pues es la cantidad total de colesteról presente en la sangre del paciente, y toma valores desde el $-0.0763945037500033$ hasta el $0.18523444326019867$.
#     <li>S5:</li>
#     Esta varialbe es cuantitativa contínua, pues es la cantidad de trigliceridos presentes en la sangre del paciente, y toma valores desde el $-0.12609712083330468$ hasta el $0.13359728192191356$.
#     <li>S6:</li>
#     Esta variable es cuantitativa contínua, pues es la cantidad de azúcar en la sangre del paciente, y toma valores desde el $-0.13776722569000302$ hasta el $0.13561183068907107$.gar le
#
# <b><b>
# <p>No mencione las medias ni las deviaciónes estandar de las variables pues se encuentran estandarizadas, y todas tienen meidas iguales a $0$ (Si bien no son ceros exactos, son ceros numéricos, es decir, valores muy cercanos al 0, como por ejemplo, la media de la variable $age$ es de $-1.4\times 10^{-19}$), al igual que las desviaciones estandar, la cual es aproximadamente de $0.047565$ para todas las variables.</p>vel
# </ol>

# %% [markdown]
# #### Instrucción 2:
# <p style='text-align: justify;'>Reproduce la siguiente celda para incluir en nuestro dataframe a la variable que buscaremos predecir con nuestro modelo de regresión.</p>

# %%
df['target'] = diabetes.target
df.head(10)
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5 -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# 6 -0.045472  0.050680 -0.047163 -0.015999 -0.040096 -0.024800  0.000779
# 7  0.063504  0.050680 -0.001895  0.066629  0.090620  0.108914  0.022869
# 8  0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# 9 -0.070900 -0.044642  0.039062 -0.033213 -0.012577 -0.034508 -0.024993
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# ...

# %% [markdown]
# #### Instrucción 3:
# <p style='text-align: justify;'>Utiliza la instrucción <b>corr()</b> para obtener la correlación de variables de nuestro dataframe. Guarda esta correlación en una variable llamada <b>corr</b>.</p>

# %% [markdown]
# <p style='text-align: justify;'>Construye un mapa de calor con la información de la matriz de correlaciones obtenida en la instrucción anterior. <b>Nota:</b> puedes usar los parametros que quieras en el mapa de calor siempre y cuando el resultado sea legible, pero se te recomiendan los siguiente figsize =(10,8), linewidth = 0.5, annot = True, cmap = "YlGnBu".</p> </p>

# %%
corr = df.corr()

plt.subplots(figsize=(10,8))
sns.heatmap(corr,annot=True,linewidth=.5,cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# #### Instrucción 4:
# <p style='text-align: justify;'>De forma similar a lo que utilizamos en nuestra libreta practica titulada "<b>Regresión Lineal y Regresión Múltiple</b>" obten un arreglo donde se muestren las caracteristicas más relevantes y grabalas en una variable llamada <b>relevant_features</b>. Para este ejercicio considerea como una caracteristica relevante a toda aquella que tenga una correlación mayor al 40%.</p>

# %%
#Calculamos los valores absolutos de la matriz de correlacion
abs = np.abs(corr['target'])
print('-'*50)
print(abs)
print('-'*50)

#Vemos que variables tienen una correlación mayor al 40% con la variable objetivo
relevantes = abs[abs>0.4].index
relevant_features = relevantes.drop('target')
print(f'Variables relevantes :{relevant_features}')

#Modificamos df para que solo tenga variables relevantes
#df = df[relevant_features]
# Out:
# --------------------------------------------------
# age       0.187889
# sex       0.043062
# bmi       0.586450
# bp        0.441482
# s1        0.212022
# s2        0.174054
# s3        0.394789
# s4        0.430453
# s5        0.565883
# s6        0.382483
# target    1.000000
# Name: target, dtype: float64
# --------------------------------------------------
# Variables relevantes :Index(['bmi', 'bp', 's4', 's5'], dtype='object')

# %% [markdown]
# #### Instrucción 5:
# <p style='text-align: justify;'>En la siguiente sección de nuestra libreta  analizaremos a la variable "<b>Body mass index</b>" (bmi). Crea una variable <b>x</b> donde grabes la columna <b>bmi</b> y una variable <b>y</b> donde almacenemos la información de la columna <b>target</b>. Para comprobar que lo anterior sea un exito imprime cada una de las nuevas variables. <b>Nota:</b> es muy recomendable a cada una de las variables les des la forma de una columna de datos con ayuda de la instrucción <b>values.reshape(-1, 1)</b>.</p>

# %%
x = df['bmi'].values.reshape(-1,1)
y = df['target'].values.reshape(-1,1)

# %%
print(x)
# Out:
# [[ 0.06169621]
#  [-0.05147406]
#  [ 0.04445121]
#  [-0.01159501]
#  [-0.03638469]
#  [-0.04069594]
#  [-0.04716281]
#  [-0.00189471]
#  [ 0.06169621]
#  [ 0.03906215]
#  [-0.08380842]
#  [ 0.01750591]
#  [-0.02884001]
#  [-0.00189471]
#  [-0.02560657]
#  [-0.01806189]
#  [ 0.04229559]
#  [ 0.01211685]
#  [-0.0105172 ]
#  [-0.01806189]
#  [-0.05686312]
#  [-0.02237314]
#  [-0.00405033]
#  [ 0.06061839]
#  [ 0.03582872]
#  [-0.01267283]
#  [-0.07734155]
#  [ 0.05954058]
#  [-0.02129532]
#  [-0.00620595]
#  [ 0.04445121]
#  [-0.06548562]
#  [ 0.12528712]
#  [-0.05039625]
#  [-0.06332999]
#  [-0.03099563]
#  [ 0.02289497]
#  [ 0.01103904]
#  [ 0.07139652]
#  [ 0.01427248]
#  [-0.00836158]
#  [-0.06764124]
#  [-0.0105172 ]
#  [-0.02345095]
#  [ 0.06816308]
#  [-0.03530688]
#  [-0.01159501]
#  [-0.0730303 ]
#  [-0.04177375]
#  [ 0.01427248]
#  [-0.00728377]
#  [ 0.0164281 ]
#  [-0.00943939]
#  [-0.01590626]
#  [ 0.0250506 ]
#  [-0.04931844]
#  [ 0.04121778]
#  [-0.06332999]
# ...

# %%
print(y)
# Out:
# [[151.]
#  [ 75.]
#  [141.]
#  [206.]
#  [135.]
#  [ 97.]
#  [138.]
#  [ 63.]
#  [110.]
#  [310.]
#  [101.]
#  [ 69.]
#  [179.]
#  [185.]
#  [118.]
#  [171.]
#  [166.]
#  [144.]
#  [ 97.]
#  [168.]
#  [ 68.]
#  [ 49.]
#  [ 68.]
#  [245.]
#  [184.]
#  [202.]
#  [137.]
#  [ 85.]
#  [131.]
#  [283.]
#  [129.]
#  [ 59.]
#  [341.]
#  [ 87.]
#  [ 65.]
#  [102.]
#  [265.]
#  [276.]
#  [252.]
#  [ 90.]
#  [100.]
#  [ 55.]
#  [ 61.]
#  [ 92.]
#  [259.]
#  [ 53.]
#  [190.]
#  [142.]
#  [ 75.]
#  [142.]
#  [155.]
#  [225.]
#  [ 59.]
#  [104.]
#  [182.]
#  [128.]
#  [ 52.]
#  [ 37.]
#  [170.]
#  [170.]
#  [ 61.]
#  [144.]
#  [ 52.]
#  [128.]
#  [ 71.]
#  [163.]
#  [150.]
#  [ 97.]
#  [160.]
#  [178.]
#  [ 48.]
#  [270.]
#  [202.]
#  [111.]
#  [ 85.]
#  [ 42.]
#  [170.]
#  [200.]
#  [252.]
#  [113.]
#  [143.]
#  [ 51.]
#  [ 52.]
#  [210.]
#  [ 65.]
#  [141.]
#  [ 55.]
#  [134.]
#  [ 42.]
#  [111.]
#  [ 98.]
#  [164.]
#  [ 48.]
#  [ 96.]
#  [ 90.]
#  [162.]
#  [150.]
#  [279.]
#  [ 92.]
#  [ 83.]
# ...

# %% [markdown]
# #### Instrucción 6:
# <p style='text-align: justify;'>Repoduce la siguiente celda, para divir el conjunto de datos en entrenamiento y prueba. Una vez que la reproduzcas la celda completa la información solicitada en la celda markdown.</p>

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.30, random_state=100)

#print(f'Longitud de x: {len(x)}')
#print(f'Longitud de x_test: {len(x_test)}')
#print(f'Longitud de x_train: {len(x_train)}')

# %% [markdown]
# - El tamaño del conjunto original <b>x</b> es: 442
# - El tamaño de <b>x_test</b> es: 133
# - El tamaño de <b>x_train</b> es: 309

# %% [markdown]
# #### Instrucción 7:
# <p style='text-align: justify;'>Con ayuda de la paquetería de sklearn.linear_model construye un modelo de regresión lineal que se ajuste a nuestros datos de entrenamiento y utiliza el modelo para obtener los dos siguientes conjuntos de respuestas: "<b>y_train_predict</b>" y "<b>y_test_predict</b>".</p>

# %%
from sklearn.linear_model import LinearRegression

modelo = LinearRegression()
modelo.fit(x_train,y_train)

y_train_predict = modelo.predict(x_train)
y_test_predict = modelo.predict(x_test)

# %% [markdown]
# #### Instrucción 8:
# <p style='text-align: justify;'>Utilizando la función <b>plt.scatter</b> construye una grafica donde se muestren el conjuto de entrenamiento en color azul, el conjunto de prueba en naranja y una línea recta roja donde se muestre la predicción devuelta por nuestro modelo.</p>

# %% [markdown]
# <p style='text-align: justify;'><b>Nota 1:</b> apoyate en el ejemplo de la libreta titulada "<b>Regresión Lineal y Regresión Múltiple</b>" en caso de que tengas algún problema o duda con esta sección.</p>

# %% [markdown]
# <p style='text-align: justify;'><b>Nota 2:</b> Al momento de construir las x_plot para graficar la línea recta creada por el modelo es conveniente que uses valores de inicio y de fin muy cercanos al valor minimo y maximo de la variable en cuestion.</p>
# - Valor minimo de la variable bmi: -9.027530e-02
# - Valor maximo de la variable bmin: 1.705552e-01

# %%
plt.scatter(x_train,y_train,label='Entrenamiento')
plt.scatter(x_test,y_test,label='Prueba')

x_recta = np.linspace(start=np.min(df['bmi']),
                      stop=np.max(df['bmi']),
                     num=100)
y_recta = modelo.predict(x_recta.reshape(-1,1))

plt.plot(x_recta,y_recta,'r')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### Instrucción 9:
# <p style='text-align: justify;'>Reproduce la siguiente celda para obtener la metrica r2_score tanto para el conjunto de entrenamiento como en el de prueba.</p>

# %%
from sklearn.metrics import r2_score
print("Entrenamiento", r2_score(y_train, y_train_predict))
print("Prueba", r2_score(y_test, y_test_predict))
# Out:
# Entrenamiento 0.3431371813669878
# Prueba 0.330175259976058

# %% [markdown]
# #### Instrucción 10:
# <p style='text-align: justify;'>Repite las instrucciones cinco hasta la nueve pero ahora sustituye la variable "<b>Body mass index</b>" (bmi) por la variable "<b>BAverage blood pressure</b>" (bp). Una vez que termines de realizar las instrucciones, agrega en una celda de tipo <b>markdown</b> que significa que la metrica r2_score sea menor para esta variable con respecto a la variable bmi.</p>

# %%
# Instrucción 5
x = df['bp'].values.reshape(-1,1)

#Instrucción 6
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.30, random_state=100)

#Instrucción 7
#Creación de modelo
modelo2 = LinearRegression()
#Ajuste de modelo
modelo2.fit(x_train,y_train)
#Prediccion de modelo
y_train_predict = modelo2.predict(x_train)
y_test_predict = modelo2.predict(x_test)

#Instruccion 8
plt.scatter(x_train,y_train,label='Entrenamiento')
plt.scatter(x_test,y_test,label='Prueba')

x_recta = np.linspace(start=np.min(df['bp']),
                      stop=np.max(df['bp']),
                     num=100)
y_recta = modelo.predict(x_recta.reshape(-1,1))

plt.plot(x_recta,y_recta,'r')
plt.legend()
plt.grid(True)
plt.title('Presion como variable explicativa')
plt.show()

#Instruccion 9
print("Entrenamiento", r2_score(y_train, y_train_predict))
print("Prueba", r2_score(y_test, y_test_predict))
# Out:
# Entrenamiento 0.16607794023507894
# Prueba 0.2500904324644452

# %% [markdown]
# <h3>Comparación de coeficinetes de determinación</h3>
# <p style='text-align: justify';>
#     El $r^{2}$ o tambien conocido como coeficiente de determinación, nos dice que porción de la varianza de la variable respuesta es explicada por el modelo, por lo que es "deseable" que un modelo tenga una $r^{2}$ alta.<br> En este caso el modelo que tiene la variable $bmi$ como variable explicativa, tiene una $r^{2} = 0.3431371813669878$, mientras que el modleo que tiene la variable $bp$ como variable independiente, tiene una $r^{2} = 0.16607794023507894$ (Ambas calculadas sobre el conjunto de entrenamiento).
#
# <br> Esto nos dice, que aunque ambos modelos explican una parte pequeña de la variabilidad de la variable respuesta, el primer modelo (El que tiene la variable $bmi$ como variable explicativa), explica mejor la variabilidad de los datos, por lo que este modelo tiene un ajuste ligeramente mejor que el segundo modelo (Aque con la variable $bp$ como variable explicativa).
#     </p>

# %% [markdown]
# ## Entrega de la actividad:
# <p style='text-align: justify;'>Una vez que hayas terminado la actividad graba tu libreta de jupyter y subela a la plataforma.</p>
