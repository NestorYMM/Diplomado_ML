# %% [markdown]
# ## Sección donde incluimos la mayoría de las librerias que utilizaremos en la actividad.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
#sns.set_style("whitegrid")
import numpy as np
import pandas as pd

# %% [markdown]
# ## Obtención del conjunto de los datos.

# %%
from sklearn.datasets import load_wine
wine = load_wine()

# %% [markdown]
# #### Instrucción 1:
# <p style='text-align: justify;'>Reproduce la siguiente celda de código "print(wine.DESCR)" y analiza la base de datos que utilizarás en esta actividad. Agrega una celda de tipo <b>markdown</b> en donde escribas de que trata la base de datos, incluyendo cuantos renglones y columnas tiene la base de datos.</p>

# %%
print(wine.DESCR)
# Out:
# .. _wine_dataset:
#
# Wine recognition dataset
# ------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 178
# :Number of Attributes: 13 numeric, predictive attributes and the class
# :Attribute Information:
#     - Alcohol
#     - Malic acid
#     - Ash
#     - Alcalinity of ash
#     - Magnesium
#     - Total phenols
#     - Flavanoids
#     - Nonflavanoid phenols
#     - Proanthocyanins
#     - Color intensity
#     - Hue
#     - OD280/OD315 of diluted wines
#     - Proline
#     - class:
#         - class_0
#         - class_1
#         - class_2
#
# :Summary Statistics:
#
# ============================= ==== ===== ======= =====
#                                 Min   Max   Mean     SD
# ============================= ==== ===== ======= =====
# Alcohol:                      11.0  14.8    13.0   0.8
# Malic Acid:                   0.74  5.80    2.34  1.12
# Ash:                          1.36  3.23    2.36  0.27
# ...

# %% [markdown]
# <h1> Descripción de los datos</h1>
# El conjunto de datos cuenta con 178 filas (Cada una es un ejemplo de un vino) y 13 columnas o atributos (Todos variables cuantitativas contínuas), los cuales son los siguientes:
# <div>
#     <ol>
#         <li>Alcohól:</li>
#         Toma valores desde el 11 hasta el 14.8, teniendo una media de 13 y una desviación estandar de 0.8
#         <li>Malic Acid:</li>
#         Toma valores desde el 0.74 hasta el 5.8, teniendo una media de 2.34 y una desviación estandar de 1.12
#         <li>Ash:</li>
#         Toma valores desde el 1.36 hasta el 3.23, teniendo una media de 2.36 y una desviación estandar de 0.27
#         <li>Alcalinity of Ash:</li>
#         Toma valores desde el 10.6 hasta el 30, teniendo una media de 19.5 y una desviación estandar de 3.3
#         <li>Magnesium:</li>
#         Toma valores desde el 70 hasta el 162, teniendo una media de 99.7 y una desviación estandar de 14.3
#         <li>Total Phenols:</li>
#         Toma valores desde el 0.98 hasta el 3.88, teniendo una media de 2.29 y una desviación estandar de 0.63
#         <li>Flavonoids:</li>
#         Toma valores desde el 0.34 hasta el 5.08, teniendo una media de 2.03 y una desviación estandar de 1
#         <li>Nonflavanoid Phenols:</li>
#         Toma valores desde el 0.13 hasta el 0.66, teniendo una media de 0.36 y una desviación estandar de 0.12
#         <li>Proanthocyanins:</li>
#         Toma valores desde el 0.41 hasta el 3.58, teniendo una media de 1.59 y una desviación estandar de 0.57
#         <li>Colour Intensity:</li>
#         Toma valores desde el 1.3 hasta el 13, teniendo una media de 5.1 y una desviación estandar de 2.3
#         <li>Hue:</li>
#         Toma valores desde el 0.48 hasta el 1.71, teniendo una media de 0.96 y una desviación estandar de 0.23
#         <li>OD280/OD315 of diluted wines:</li>
#         Toma valores desde el 1.27 hasta el 4, teniendo una media de 2.61 y una desviación estandar de 0.71
#         <li>Proline:</li>
#         Toma valores desde el 278 hasta el 1680, teniendo una media de 746 y una desviación estandar de 315
#     </ol>
# </div>
# Adicionalmente se cuenta con una columna extra llamada $class$ la cuál es una variable cualitativa que solo tiene uno de los siguientes tres valores
# <div>
#     <ul>
#         <li>class_0</li>
#         <li>class_1</li>
#         <li>class_2</li>
#     </ul>
# </div>
# Hay 59 filas con datos de vinos que pertenecen a la clase 0, 71 a la clase 1, y 48 a la clase 2.
# <br> El conjunto no contiene ningun valor nulo.

# %% [markdown]
# #### Instrucción 2:
# <p style='text-align: justify;'>Reproduce la siguiente celda de código para construir un dataframe (<b>df</b>) con la información de nuestro conjunto de datos, posteriormente incluye dos celdas de tipo <b>code</b> donde utilices la instrucción <b>head()</b> para visualizar los primeros diez elementos del conjunto de datos y la instrucción <b>describe()</b> para obtener información estadística básica.</p>

# %%
df = pd.DataFrame(wine.data, columns = wine.feature_names)
df['Objective'] = wine.target

# %%
df.head(10)
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
# 5    14.20        1.76  2.45               15.2      112.0           3.27
# 6    14.39        1.87  2.45               14.6       96.0           2.50
# 7    14.06        2.15  2.61               17.6      121.0           2.60
# 8    14.83        1.64  2.17               14.0       97.0           2.80
# 9    13.86        1.35  2.27               16.0       98.0           2.98
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# ...

# %%
df.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %% [markdown]
# #### Instrucción 4:
# <p style='text-align: justify;'>En la siguiente celda escribe las instrucciones adecuadas para construir un histograma a partir de la columna titulada "<b>alcohol</b>". Utiliza el parámetro <b>bins = 20</b>, para construir tu gráfico.</p>

# %%
sns.histplot(df,x='alcohol',bins=20)
plt.title('Alcohol en la muestra')
plt.grid(axis='y')
plt.show()
# Out:
# D:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### Instrucción 5:
# <p style='text-align: justify;'>Una vez que construiste correctamente la visualización de datos solicitada contesta en una celda de tipo <b>markdown</b> las siguientes preguntas:</p>
# - ¿Cuál es la mayor concentración de alcohol que se incluye en este grafico?
# - ¿Cuál son las dos concentraciones que más se repiten en nuestro conjunto de datos?
# - ¿Cuál son las dos concentraciones que menos se repiten en nuestro conjunto de datos?

# %% [markdown]
# ##### Respuestas
# - La mayor concentración de alcohól que se incluye en el grafico se encuentra entre el 14.5 y el 15.0 (El registro que tiene el mayor valor en la variable alcohol, fue de 14.83)
# - Las dos concentraciones que más se repiten en nuestro conjunto de datos, parece ser que son aquellas entre 13.8 y 14, y despues las que se encuentran entre 12.4 y 12.6 (Aproximadamente)
# - Las dos concentraciones que menos se repiten son aquellas entre 11 y 11.3, y aquellas entre 14.5 y 15 (Estos intervalos son aproximados)

# %% [markdown]
# #### Instrucción 6:
# <p style='text-align: justify;'>Utiliza la instrucción <b>corr()</b> para obtener la correlación de variables de nuestro dataframe. Guarda esta correlación en una variable llamada <b>corr</b>. E imprime la correlación con ayuda de la instrucción <b>print()</b>.</p>

# %%
corr = df.corr()
print(corr)
# Out:
#                                alcohol  malic_acid       ash  \
# alcohol                       1.000000    0.094397  0.211545
# malic_acid                    0.094397    1.000000  0.164045
# ash                           0.211545    0.164045  1.000000
# alcalinity_of_ash            -0.310235    0.288500  0.443367
# magnesium                     0.270798   -0.054575  0.286587
# total_phenols                 0.289101   -0.335167  0.128980
# flavanoids                    0.236815   -0.411007  0.115077
# nonflavanoid_phenols         -0.155929    0.292977  0.186230
# proanthocyanins               0.136698   -0.220746  0.009652
# color_intensity               0.546364    0.248985  0.258887
# hue                          -0.071747   -0.561296 -0.074667
# od280/od315_of_diluted_wines  0.072343   -0.368710  0.003911
# proline                       0.643720   -0.192011  0.223626
# Objective                    -0.328222    0.437776 -0.049643
#
# ...

# %% [markdown]
# #### Instrucción 7:
# <p style='text-align: justify;'>Construye un mapa de calor con la información de la matriz de correlaciones obtenida en la instrucción anterior. <b>Nota:</b> puedes usar los parámetros que quieras en el mapa de calor siempre y cuando el resultado sea legible, pero se te recomiendan los siguiente figsize =(10,8), linewidth = 0.5, annot = True, cmap = "YlGnBu".</p>

# %%
plt.figure(figsize=(10, 8))
heatmap = sns.heatmap(corr, linewidths=0.5, annot=True, annot_kws={"size": 10},cmap="YlGnBu")

plt.show()

# %%
# Se hizo el mapa de calor duplicado pues en el primero no se mostraban
# los coeficientes de correlación correctamente
fig, ax = plt.subplots(figsize=(10, 8))
cax = ax.matshow(corr, cmap="YlGnBu")
fig.colorbar(cax)
ax.set_xticks(np.arange(len(corr.columns)))
ax.set_yticks(np.arange(len(corr.columns)))
ax.set_xticklabels(corr.columns, rotation=45, ha="left", fontsize=10)
ax.set_yticklabels(corr.columns, fontsize=10)
for (i, j), val in np.ndenumerate(corr.values):
    ax.text(j, i, f'{val:.2f}', ha='center', va='center', fontsize=8, color='black')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Instrucción 8:
# <p style='text-align: justify;'>Una vez que construiste correctamente la visualización de datos solicitada contesta en una celda de tipo <b>markdown</b> las siguientes preguntas:</p>
# - ¿Cuáles son las 2 variables que tienen mayor correlación con respecto a la variable "alcohol"?
# - ¿Cuáles son las 2 variables que más se relacionan con la intensidad del color del vino?
# - ¿Cuáles son las 2 variables menos relacionadas con la presencia de magnesio en el vino?
# <br>
# <br><b>Nota:</b> Al responder las preguntas anteriores no considere la correlación de una variable sobre sí misma.

# %% [markdown]
# ##### Respuestas
# - Las dos variables con una mayor correlación con respoecto a la varible alcohól son color_intensity, y proline.
# - Las dos variables que más se relacionan con la intensidad del color son alcohól y proline, aunque esto solo considerando la relación cuando el coeficiente de correlación es positivo, porque tambien las variables hue y od280/od315_of_diluted_wines tambien están muy relacionadas con la intensidad del color, aunque la relación parece ser inversamente proporcional.
# - Igual que en el punto anterior, si consideramos el coeficiente de correlación negativo como signo de no correlación, podemos decir que la alcalinidad de la ceniza y la variable $nonflavanoid_phenols$ son los menos relacionados con la presencia de magnesio en el vino. Pero si consideramos que entre más cercano al 0 se encuentre el coeficiente de correlación entre dos variables, hay menos relación entre estas, entonces podemos decir que las dos variables menos relacionadas con la presenci de magnesio en el vino son el ácido málico y la variable hue

# %% [markdown]
# #### Instrucción 9:
# <p style='text-align: justify;'>Utilizando la instrucción <b>sns.joinplot</b> construye una visualización de datos donde se evidencie la relación entre el grado de alcohol y la intensidad del color del vino. <b>Nota:</b> Quizás sea conveniente grabar en una variable <b>x</b> a la columna del grado de alcohol (x = df['alcohol']) y en otra variable <b>y</b> la columna con los datos de la intensidad del color (y = df['color_intensity']). </p>

# %%
x = df['alcohol']
y = df['color_intensity']

sns.jointplot(df,x='alcohol',y='color_intensity')
plt.show()
# Out:
# D:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### Instrucción 10:
# <p style='text-align: justify;'>En la siguiente celda escribe que significa que algunas regiones de la cuadricula obtenida en la visualización anterior, estén muy pobladas de puntos mientras que en otras secciones este casi vacio. </p>

# %% [markdown]
# ##### Respuesta
# - Simplemente significa que en esa zona hay una mayor cantidad de datos en esas secciones, posiblemente sean "aglomeraciones" de datos de vinos que pertenecen a la misma clasificación. Para mostrar esto, se repetirá la grafica pasada (jointplot) pero separando por colores de acuerdo a la clase de vino.

# %%
sns.jointplot(df,x='alcohol',y='color_intensity',hue='Objective')
plt.show()
# Out:
# D:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# D:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ## Entrega de la actividad:
# <p style='text-align: justify;'>Una vez que hayas terminado la actividad graba tu libreta de jupyter y súbela a la plataforma.</p>
